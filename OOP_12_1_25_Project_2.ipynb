# %% [markdown]
# <a href="https://colab.research.google.com/github/hewettac/OOP-New/blob/main/OOP_12_1_25_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

mydata = {"cars": ["BMW", "Audi", "Toyota"], "prize":[75000, 72000, 55000]}

df = pd.DataFrame(mydata)

df

JediCouncil = {"First Name": ["Anakin", "Obi-Wan", "Mace", "Coleman", "Ki-Adi", "Plo"], "Last Name":["Skywalker", "Kenobi", "Windu", "Trebor", "Mundi", "Koon"],
               "Master":["No", "Yes", "Yes", "Yes", "Yes", "Yes"]}

df2 = pd.DataFrame(JediCouncil)

df2.head(3)


df = pd.read_csv("data.csv")
df.head(10)

df.dropna()
df.fillna(120, inplace=True)
df.head(10)



x = df["Calories"].mean
print("Mean: ", x)

df.fillna({"Calories":x}, inplace=True)
# Out:
# Mean:  <bound method Series.mean of 0      409.1
# 1      479.0
# 2      340.0
# 3      282.4
# 4      406.0
#        ...
# 164    290.8
# 165    300.0
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64>
